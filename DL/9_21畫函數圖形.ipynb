# %% [markdown]
# 讀入基本套件
#
# 支援 Markdown語法，還有LaTex打數學符號

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 畫函數圖形

# %% [markdown]
# $$f(x)=\log(x)$$

# %%
x = np.linspace(0.5, 2, 200)
print(x)
# Out:
# [0.5        0.50753769 0.51507538 0.52261307 0.53015075 0.53768844
#  0.54522613 0.55276382 0.56030151 0.5678392  0.57537688 0.58291457
#  0.59045226 0.59798995 0.60552764 0.61306533 0.62060302 0.6281407
#  0.63567839 0.64321608 0.65075377 0.65829146 0.66582915 0.67336683
#  0.68090452 0.68844221 0.6959799  0.70351759 0.71105528 0.71859296
#  0.72613065 0.73366834 0.74120603 0.74874372 0.75628141 0.7638191
#  0.77135678 0.77889447 0.78643216 0.79396985 0.80150754 0.80904523
#  0.81658291 0.8241206  0.83165829 0.83919598 0.84673367 0.85427136
#  0.86180905 0.86934673 0.87688442 0.88442211 0.8919598  0.89949749
#  0.90703518 0.91457286 0.92211055 0.92964824 0.93718593 0.94472362
#  0.95226131 0.95979899 0.96733668 0.97487437 0.98241206 0.98994975
#  0.99748744 1.00502513 1.01256281 1.0201005  1.02763819 1.03517588
#  1.04271357 1.05025126 1.05778894 1.06532663 1.07286432 1.08040201
#  1.0879397  1.09547739 1.10301508 1.11055276 1.11809045 1.12562814
# ...

# %%
y = np.log(x)
y
# Out:
# array([-0.69314718, -0.67818431, -0.66344203, -0.64891393, -0.63459387,
#        -0.62047599, -0.60655465, -0.59282446, -0.57928023, -0.56591701,
#        -0.55273   , -0.53971463, -0.52686649, -0.51418133, -0.50165507,
#        -0.48928378, -0.47706367, -0.46499109, -0.45306252, -0.44127456,
#        -0.42962394, -0.4181075 , -0.40672218, -0.39546502, -0.38433318,
#        -0.3733239 , -0.3624345 , -0.3516624 , -0.34100511, -0.33046019,
#        -0.32002532, -0.3096982 , -0.29947665, -0.28935852, -0.27934174,
#        -0.2694243 , -0.25960426, -0.24987971, -0.24024881, -0.23070979,
#        -0.2212609 , -0.21190046, -0.20262682, -0.1934384 , -0.18433363,
#        -0.17531101, -0.16636907, -0.15750639, -0.14872156, -0.14001323,
#        -0.13138008, -0.12282083, -0.11433422, -0.10591902, -0.09757405,
#        -0.08929814, -0.08109016, -0.072949  , -0.06487359, -0.05686286,
#        -0.0489158 , -0.0410314 , -0.03320867, -0.02544667, -0.01774445,
# ...

# %%
plt.plot(x, y)

# %% [markdown]
# $$f(x) = 2x^2 + 5x -\sin(4x)$$

# %%
x = np.linspace(-10, 10, 200)
y = 2*x**2 + 5*x - np.sin(4*x)

# %%
plt.plot(x, y)

# %%
plt.xkcd()

# %%
plt.plot(x, y)
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'xkcd Script' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Neue' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Comic Sans MS' not found.
# ...
